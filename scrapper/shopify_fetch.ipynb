# %% [markdown]
# # Test Shopify Product Fetch
# Fetch the first product from Shopify and display raw JSON

# %%
import os
import json
import requests
from dotenv import load_dotenv
import sys

# Add parent directory to path to access .env
load_dotenv('../.env', override=True)
# Out:
# True

# %%
# Initialize Shopify API configuration
shop_url = os.getenv('SHOPIFY_SHOP_URL', '').rstrip('/')
access_token = os.getenv('SHOPIFY_ACCESS_TOKEN')
api_version = os.getenv('SHOPIFY_API_VERSION', '2024-01')

print(f"Shop URL: {shop_url}")
print(f"API Version: {api_version}")
print(f"Access Token: {'Set' if access_token else 'Not set'}")
# Out:
# Shop URL: https://ustzsu-tp.myshopify.com
# API Version: 2025-07
# Access Token: Set

# %%
# Build API endpoint
base_url = f"{shop_url}/admin/api/{api_version}"
endpoint = f"{base_url}/products.json"

# Set up headers
headers = {
    'X-Shopify-Access-Token': access_token,
    'Content-Type': 'application/json'
}

# Fetch just 1 product
params = {
    'limit': 1
}

print(f"Endpoint: {endpoint}")
# Out:
# Endpoint: https://ustzsu-tp.myshopify.com/admin/api/2025-07/products.json

# %%
# Make the API request
try:
    response = requests.get(endpoint, headers=headers, params=params)
    response.raise_for_status()
    
    data = response.json()
    
    print(f"Status Code: {response.status_code}")
    print(f"Number of products returned: {len(data.get('products', []))}")
    
except requests.exceptions.RequestException as e:
    print(f"Error: {e}")
    if hasattr(e, 'response') and e.response is not None:
        print(f"Response Status: {e.response.status_code}")
        print(f"Response Body: {e.response.text}")
# Out:
# Status Code: 200
# Number of products returned: 1

# %%
# Display the raw JSON of the first product
if 'products' in data and len(data['products']) > 0:
    first_product = data['products'][0]
    print(json.dumps(first_product, indent=2))
else:
    print("No products found")
    print("Full response:")
    print(json.dumps(data, indent=2))
# Out:
# {
#   "id": 9092518707451,
#   "title": "Classic Cotton T-Shirt",
#   "body_html": "<p>Our premium cotton t-shirt is perfect for everyday comfort. Made from 100% organic cotton, this versatile piece features a relaxed fit and soft texture that gets better with every wash.</p><ul>\n<li>100% organic cotton</li>\n<li>Pre-shrunk for lasting fit</li>\n<li>Reinforced seams for durability</li>\n<li>Machine washable</li>\n</ul>",
#   "vendor": "Cotton Comfort Co.",
#   "product_type": "Apparel",
#   "created_at": "2025-08-25T11:26:57-04:00",
#   "handle": "classic-cotton-t-shirt",
#   "updated_at": "2025-08-25T11:48:44-04:00",
#   "published_at": "2025-08-25T11:27:01-04:00",
#   "template_suffix": "",
#   "published_scope": "global",
#   "tags": "casual, ceramic, coffee, comfortable, cotton, gift, kitchen, mug, organic, unisex",
#   "status": "active",
#   "admin_graphql_api_id": "gid://shopify/Product/9092518707451",
#   "variants": [
#     {
#       "id": 47466598662395,
#       "product_id": 9092518707451,
#       "title": "Red / S",
#       "price": "24.99",
#       "position": 1,
#       "inventory_policy": "deny",
#       "compare_at_price": "34.99",
#       "option1": "Red",
#       "option2": "S",
#       "option3": null,
#       "created_at": "2025-08-25T11:29:40-04:00",
#       "updated_at": "2025-08-25T11:48:35-04:00",
#       "taxable": true,
#       "barcode": "",
#       "fulfillment_service": "manual",
#       "grams": 136,
#       "inventory_management": "shopify",
#       "requires_shipping": true,
#       "sku": "CCT-001",
#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49531974942971,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47

#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49532029337851,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47466653057275",
#       "image_id": null
#     },
#     {
#       "id": 47466598727931,
#       "product_id": 9092518707451,
#       "title": "White / S",
#       "price": "24.99",
#       "position": 11,
#       "inventory_policy": "deny",
#       "compare_at_price": "34.99",
#       "option1": "White",
#       "option2": "S",
#       "option3": null,
#       "created_at": "2025-08-25T11:29:40-04:00",
#       "updated_at": "2025-08-25T11:48:37-04:00",
#       "taxable": true,
#       "barcode": "",
#       "fulfillment_service": "manual",
#       "grams": 136,
#       "inventory_management": "shopify",
#       "requires_shipping": true,
#       "sku": "CCT-0011",
#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49531975008507,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47466598727931",
#       "image_id": null
#     },
#     {
#       "id": 47466653090043,
#       "product_id": 9092518707451,
#       "title": "White / M",
#       "price": "24.99",
#       "position": 12,
#       "inventory_policy": "deny",
#       "compare_at_price": "34.99",
#       "option1": "White",
#       "option2": "M",
#       "option3": null,
#       "created_at": "2025-08-25T11:48:36-04:00",
#       "updated_at": "2025-08-25T11:48:36-04:00",
#       "taxable": true,
#       "barcode": "",
#       "fulfillment_service": "manual",
#       "grams": 136,
#       "inventory_management": "shopify",
#       "requires_shipping": true,
#       "sku": "CCT-0012",
#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49532029370619,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47466653090043",
#       "image_id": null
#     },
#     {
#       "id": 47466653122811,
#       "product_id": 9092518707451,
#       "title": "White / L",
#       "price": "24.99",
#       "position": 13,
#       "inventory_policy": "deny",
#       "compare_at_price": "34.99",
#       "option1": "White",
#       "option2": "L",
#       "option3": null,
#       "created_at": "2025-08-25T11:48:36-04:00",
#       "updated_at": "2025-08-25T11:48:36-04:00",
#       "taxable": true,
#       "barcode": "",
#       "fulfillment_service": "manual",
#       "grams": 136,
#       "inventory_management": "shopify",
#       "requires_shipping": true,
#       "sku": "CCT-0013",
#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49532029403387,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47466653122811",
#       "image_id": null
#     },
#     {
#       "id": 47466653155579,
#       "product_id": 9092518707451,
#       "title": "White / XL",
#       "price": "24.99",
#       "position": 14,
#       "inventory_policy": "deny",
#       "compare_at_price": "34.99",
#       "option1": "White",
#       "option2": "XL",
#       "option3": null,
#       "created_at": "2025-08-25T11:48:36-04:00",
#       "updated_at": "2025-08-25T11:48:36-04:00",
#       "taxable": true,
#       "barcode": "",
#       "fulfillment_service": "manual",
#       "grams": 136,
#       "inventory_management": "shopify",
#       "requires_shipping": true,
#       "sku": "CCT-0014",
#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49532029436155,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47466653155579",
#       "image_id": null
#     },
#     {
#       "id": 47466653188347,
#       "product_id": 9092518707451,
#       "title": "White / XS",
#       "price": "24.99",
#       "position": 15,
#       "inventory_policy": "deny",
#       "compare_at_price": "34.99",
#       "option1": "White",
#       "option2": "XS",
#       "option3": null,
#       "created_at": "2025-08-25T11:48:36-04:00",
#       "updated_at": "2025-08-25T11:48:36-04:00",
#       "taxable": true,
#       "barcode": "",
#       "fulfillment_service": "manual",
#       "grams": 136,
#       "inventory_management": "shopify",
#       "requires_shipping": true,
#       "sku": "CCT-0015",
#       "weight": 0.3,
#       "weight_unit": "lb",
#       "inventory_item_id": 49532029468923,
#       "inventory_quantity": 4,
#       "old_inventory_quantity": 4,
#       "admin_graphql_api_id": "gid://shopify/ProductVariant/47466653188347",
#       "image_id": null
#     }
#   ],
#   "options": [
#     {
#       "id": 11800045322491,
#       "product_id": 9092518707451,
#       "name": "Color",
#       "position": 1,
#       "values": [
#         "Red",
#         "Green",
#         "White"
#       ]
#     },
#     {
#       "id": 11800072782075,
#       "product_id": 9092518707451,
#       "name": "Size",
#       "position": 2,
#       "values": [
#         "S",
#         "M",
#         "L",
#         "XL",
#         "XS"
#       ]
#     }
#   ],
#   "images": [],
#   "image": null
# }

# %%
# Show product structure summary
if 'products' in data and len(data['products']) > 0:
    product = data['products'][0]
    print("Product Structure:")
    print(f"- Product ID: {product.get('id')}")
    print(f"- Title: {product.get('title')}")
    print(f"- Number of variants: {len(product.get('variants', []))}")
    print(f"- Number of images: {len(product.get('images', []))}")
    print(f"- Number of options: {len(product.get('options', []))}")
    print(f"\nTop-level keys: {list(product.keys())}")
